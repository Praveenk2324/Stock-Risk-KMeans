# %%
import pandas as pd

# %%
df = pd.read_csv(r"..\data\raw\Nifty_50_1y_dataset.csv")
df.head(10)
# Out:
#        Ticker       ASIANPAINT.NS     ASIANPAINT.NS.1     ASIANPAINT.NS.2  \
# 0       Price                Open                High                 Low
# 1        Date                 NaN                 NaN                 NaN
# 2  2025-06-05  2227.0452515829743  2236.8393653714897   2209.138568277106
# 3  2025-06-06   2225.066477788955  2228.5290771994382  2215.0743085917125
# 4  2025-06-09  2216.0636653265124  2231.6948769865094  2212.1064087812865
# 5  2025-06-10  2236.5096020141245  2236.5096020141245  2211.7481969540704
# 6  2025-06-11  2205.5577938919528  2222.4313617191465  2203.7605500158743
# 7  2025-06-12    2220.53458020989  2259.4738107081753  2204.6594529723643
# 8  2025-06-13  2171.6108865639185  2213.6453832975812   2171.411246958574
# 9  2025-06-16   2210.749588087704   2246.493850099095   2205.857321207117
#
#      ASIANPAINT.NS.3 ASIANPAINT.NS.4       BHARTIARTL.NS     BHARTIARTL.NS.1  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Columns: 253 entries, Ticker to SBILIFE.NS.4
# dtypes: object(253)
# memory usage: 498.2+ KB

# %%
df.describe()
# Out:
#        Ticker ASIANPAINT.NS ASIANPAINT.NS.1 ASIANPAINT.NS.2  \
# count     252           251             251             251
# unique    252           245             246             249
# top     Price        2880.0          2916.0          2500.0
# freq        1             3               2               2
#
#           ASIANPAINT.NS.3 ASIANPAINT.NS.4 BHARTIARTL.NS     BHARTIARTL.NS.1  \
# count                 251             251           251                 251
# unique                246             249           226                 245
# top     2371.698486328125               0        1930.0  1919.9000244140625
# freq                    2               3             4                   2
#
#        BHARTIARTL.NS.2    BHARTIARTL.NS.3  ...            SBIN.NS SBIN.NS.1  \
# count              251                251  ...                251       251
# unique             243                241  ...                249       250
# ...
